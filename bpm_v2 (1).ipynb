-lens-mainstage-tomorrowland-weekend-1-belgium-2019-07-19.html', 'https://www.1001tracklists.com/tracklist/2tmm0p09/amelie-lens-resonance-stage-medusa-sunbeach-festival-spain-2019-08-09.html', 'https://www.1001tracklists.com/tracklist/1mfk7ksk/amelie-lens-opera-stage-mainstage-street-parade-zurich-switzerland-arte.tv-2019-08-10.html', 'https://www.1001tracklists.com/tracklist/2dlhnuyk/amelie-lens-fabric-presents-amelie-lens-2019-11-22.html', 'https://www.1001tracklists.com/tracklist/2546tz0k/amelie-lens-studio-brussel-the-tunnel-2020-01-13.html']
url_bank = []
url_bank.append(marcel_dettman)
url_bank.append(joy_orbison)
url_bank.append(amelie_lens)

djs= []
tracknumbers = []
tracknames = []
artistnames = []
mixnames = []
dates = []
url_scrape = []

# %%
for url_list in url_bank:
    for url in url_list:
        count = 0
        headers = {'User-Agent': 'Chrome/51.0.2704.103'}
        page_link  = url
        page_response = requests.get(page_link, headers=headers)
        soup = bs(page_response.content, "html.parser")
        title = (page_link[48:-15])
        title = title.replace('-', ' ')
        title = (title[:-1])
        title = title.title()
        title = title.strip('/')
        title = title.strip('1/')
        title = title.strip('T/')
        title = title.strip('9/')
        title = title.strip('K/')
        date = (page_link[-15:-5])
        djname = ' '.join(title.split()[:2])
        
        tracknames_scrape = soup.find_all("div", class_="tlToogleData")
        artistnames_scrape = soup.find_all("meta", itemprop="byArtist")
        for (i, track) in enumerate(tracknames_scrape):
            if track.meta:
                trackname = track.meta['content']
                trackname = trackname.split('- ', 1)[-1]
                tracknames.append(trackname)
                mixnames.append(title)
                dates.append(date)
                djs.append(djname)                
                url_scrape.append(url)
                count +=1
                tracknumbers.append(count)
            else:
                continue
        for artist in artistnames_scrape:
            artistname = artist["content"]
            artistnames.append(artistname)

# %%
df2 = pd.DataFrame({'DJ Name': djs, 'Track Number': tracknumbers,'Track Name': tracknames, 'Artist': artistnames, 'Mix Name': mixnames, 'Date':dates})

# %%
df
# Out:
#              DJ Name  Track Number                                Track Name  \
# 0    Marcel Dettmann             1   The Black Block (Marcel Dettmann Remix)
# 1    Marcel Dettmann             2                               Casual Care
# 2    Marcel Dettmann             3                           Where Were You?
# 3    Marcel Dettmann             4  Seven Eight Nine (Marcel Dettmann Remix)
# 4    Marcel Dettmann             5                                     Pulse
# ..               ...           ...                                       ...
# 517      Joy Orbison            30                             Golden Apples
# 518      Joy Orbison            31  You'll Never Find Another Love Like Mine
# 519      Joy Orbison            32                              Golden Hills
# 520      Joy Orbison            33                              Juniper Keys
# 521      Joy Orbison            34                            Me And My Lady
#
# ...

# %%
export_csv = df.to_csv (r'C:/Users/Nsoler/Downloads/bpm_project_v3.csv', index = None, header=True)
